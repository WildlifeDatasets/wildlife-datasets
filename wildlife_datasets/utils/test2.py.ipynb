# %%
from .datasets import find_images
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-3-8f0958f55f30> in <module>
# ----> 1 from .datasets import find_images
#
# ImportError: attempted relative import with no known parent package

# %%
from v2_example import datasets
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-7-e8cd4eb87c9e> in <module>
# ----> 1 from v2_example import datasets
#
# ModuleNotFoundError: No module named 'v2_example'
